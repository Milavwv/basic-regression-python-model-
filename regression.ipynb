# %%
import numpy as np
import matplotlib.pyplot as plt
x_train = np.array([1.0,5.0,2.0])
y_train=np.array([300,500,700])
x_train = np.append(x_train,5.0)
y_train = np.append(y_train,600)

m=len(x_train)
print(f"Number of training examples is:{m}")

for i in range(m):
 x = x_train[i]
 y = y_train[i]
 print(f"(x^({i+1}),(y^{i+1})=({x},{y})")
 plt.text(x + 0.1,y,f"({x},{y})",fontsize=9)
plt.scatter(x_train,y_train,marker="X",c="r")
plt.title("Housing Prices")
plt.xlabel("Size (1000 sqft)")
plt.ylabel("price (in 1000s of dollars)")
plt.show()
# Out:
# Number of training examples is:4
# (x^(1),(y^1)=(1.0,300)
# (x^(2),(y^2)=(5.0,500)
# (x^(3),(y^3)=(2.0,700)
# (x^(4),(y^4)=(5.0,600)
